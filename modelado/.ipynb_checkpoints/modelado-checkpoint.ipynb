# %% [markdown]
# # Modelado
# Creacion e implementacion de modelos para predecir expecativa de ol de equipos.

# %% [markdown]
# ## Preparacion

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import matplotlib.image as mpimg
import os

# %%
# Importo mis funciones personalizadas
import custom_functions as cf
import custom_functions_modelado as cf_m

# %% [markdown]
# ### Imagen de la cancha para plotear

# %%
background_image = mpimg.imread('stadium.PNG')

# %% [markdown]
# ## Obtengo los datos ya filtrados

# %%
directorio_filtered = './filtered_data'

ruta_posiciones_filtered = os.path.join(directorio_filtered, 'data_posiciones_filtered.csv')
data_posiciones_filtered = pd.read_csv(ruta_posiciones_filtered)

ruta_goles_filtered = os.path.join(directorio_filtered, 'data_goles_filtered.csv')
data_goles_filtered = pd.read_csv(ruta_goles_filtered)

# %%
data_posiciones_filtered.sample(7)
# Out:
#             id  match_id  player_id           x           y  velocity_x  \
# 136545  185734       288        252 -141.269870   67.014748  -68.595289
# 21071    45691        73         72  446.301532 -169.868496   99.602114
# 198331  257231       390        365  -39.141293 -177.538801  115.244631
# 90178   132598       220        189  316.980716  -36.804272   -7.789837
# 161245  214063       325        297 -151.764349   93.103135 -132.470094
# 206654  265847       399        365 -415.570981   11.138554  -26.255642
# 209388  268683       402        378 -153.329799 -128.123255  -65.413645
#
#         velocity_y        time  team  cant_de_duplicados
# 136545   -5.864911   65.850000     2                   1
# 21071  -112.857339   54.133333     2                   1
# 198331    1.323726  128.033333     2                   1
# 90178   -12.714792   65.683333     1                   1
# 161245  -12.648409   68.983333     2                   1
# ...

# %%
data_goles_filtered.sample(7)
# Out:
#        id  match_id  player_id         player_name equipo        tick
# 305   578       220         40                       Blue   30.950000
# 568   910       358        334            Alemania    Red   68.833333
# 434   740       285        109                 Ema   Blue   26.766667
# 680  1032       410        389  kick.com/fraan_akd   Blue  182.433333
# 88    261        78         71             milo(q)    Red   14.816667
# 466   784       301         40                        Red  182.083333
# 54    227        66          2                 tnt   Blue  117.383333

# %% [markdown]
# ## Etiquetado de datos
# Etiqueto datos para entrenar y testear al modelo

# %%
# Agrupo los momentos
data_posiciones_grouped_entities = data_posiciones_filtered.groupby(['match_id', 'time']).size().reset_index(name='entities')

# %%
data_posiciones_grouped_filtered_labeled = data_posiciones_grouped_entities

data_posiciones_grouped_filtered_labeled['gol_1_ticks'] = 'none'
data_posiciones_grouped_filtered_labeled['gol_2_ticks'] = 'none'
data_posiciones_grouped_filtered_labeled['gol_3_ticks'] = 'none'
data_posiciones_grouped_filtered_labeled['gol_4_ticks'] = 'none'
data_posiciones_grouped_filtered_labeled['gol_5_ticks'] = 'none'
data_posiciones_grouped_filtered_labeled['gol_6_ticks'] = 'none'

# %%
# Diccionario para acceso rápido a los goles por match_id
goles_dict = data_goles_filtered.groupby('match_id').apply(lambda x: x[['tick', 'equipo']].to_dict('records')).to_dict()

# %%
# Iterar sobre las filas de data_grouped_entities_7ents
for index, row in data_posiciones_grouped_filtered_labeled.iterrows():
    match_id = row['match_id']
    time = row['time']
    
    if match_id in goles_dict:
        goles = goles_dict[match_id]
        
        # Filtrar goles futuros a partir del tiempo actual
        futuros_goles = [gol for gol in goles if gol['tick'] > time]
        
        for offset in range(1, 7):  # Revisar para ticks 1, 2, 3, 4, 5 y 6
            gol_cercano = next((gol['equipo'] for gol in futuros_goles if gol['tick'] <= time + offset), 'none')
            col_name = f'gol_{offset}_ticks'
            data_posiciones_grouped_filtered_labeled.at[index, col_name] = gol_cercano

# %%
match_id_test = 141
data_posiciones_grouped_filtered_labeled_idtest = data_posiciones_grouped_filtered_labeled[data_posiciones_grouped_filtered_labeled['match_id'] == match_id_test]

# Configuro para que se muestren todas las filas y columnas
pd.set_option('display.max_rows', None)  # Muestra todas las filas
pd.set_option('display.max_columns', None)  # Muestra todas las columnas
pd.set_option('display.expand_frame_repr', False)  # Evita que las columnas se corten

data_posiciones_grouped_filtered_labeled_idtest.sample(7)
# Out:
#       match_id  time  entities gol_1_ticks gol_2_ticks gol_3_ticks gol_4_ticks gol_5_ticks gol_6_ticks
# 9263       141  42.6         7        none        none        none        none         Red         Red
# 9255       141  34.6         7        none        none        none        none        none        none
# 9236       141  15.6         7        none        none        none        none        none        none
# 9241       141  20.6         7        none        none        none        none        none        none
# 9265       141  44.6         7        none        none         Red         Red         Red         Red
# 9286       141  65.6         7        none        none        none         Red         Red         Red
# 9237       141  16.6         7        none        none        none        none        none        none

# %%
# Configuro para que vuelva a los valores estandar de las filas y columnas
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.expand_frame_repr')

# %% [markdown]
# ## Resumen de los datos de entrenamiento
# Hasta aqui existen 3 tablas que seran utiles:
# * data_posiciones_filtered: datos filtrados de las posiciones de todos los jugadores en todas las instacias de todos los partidos.
# * data_goles_filtered: datos de todos los goles de todos los partidos que pasaron el filtrado.
# * data_posiciones_grouped_filtered_labeled: datos de las tuplas 'match_id' - 'time' de los momentos registrados que pasaron el filtrados, etiquetados en 6 columnas que indican si va a haber un gol (y de que equipo) dentro de 'n' ticks.

# %% [markdown]
# ## Normalizacion

# %%
ejemplo_crudo = [
-469.33245391540754,	-76.99622069143119,	-98.22601789631604,	-6.999637312526858, 1,
-245.8619738989556,	-75.90666882766646,	-157.8397101075912,	-16.180327951704218, 2, 
-183.74626114265607,	-173.07488268564356,	-127.13862497611889,	-67.44588004849875, 1, 
-153.9710503428658,	-169.40925561404282,	-104.16354380853112,	-10.323911873561645, 2, 
202.3357095430081,	-9.972215052858196,	-158.92286262264113,	3.943821709944109, 2, 
-196.1001185928374,	138.84749567600224,	-93.26727433047343,	-35.91405742771945, 1, 
-187.30970981132464, -200.66362383270027,	-120.68753894299226,	-5.273878455600128, 0
]

columns = ['x', 'y', 'velocity_x', 'velocity_y', 'team']
data_test1 = pd.DataFrame([ejemplo_crudo[i:i + 5] for i in range(0, len(ejemplo_crudo), 5)], columns=columns)

data_test1_normalizada = cf.normalizar_datos(data_test1)
print(data_test1_normalizada)
# Out:
#           x         y  velocity_x  velocity_y  team
# 0  0.000000  0.364251    0.924473    0.846708    -1
# 1  0.332710  0.367461    0.016497    0.718109     1
# 2  0.425189  0.081260    0.484106    0.000000    -1
# 3  0.469520  0.092057    0.834039    0.800143     1
# 4  1.000000  0.561665    0.000000    1.000000     1
# 5  0.406797  1.000000    1.000000    0.441686    -1
# 6  0.419884  0.000000    0.582362    0.870882     0

# %%
from sklearn.preprocessing import MinMaxScaler

data_posiciones_filtered_original = data_posiciones_filtered.copy() # Me guardo una copia del dataframe sin normalizar
data_posiciones_grouped_filtered_labeled['match_time'] = data_posiciones_grouped_filtered_labeled['match_id'].astype(str) + '_' + data_posiciones_grouped_filtered_labeled['time'].astype(str)
data_posiciones_filtered_original['match_time'] = data_posiciones_filtered_original['match_id'].astype(str) + '_' + data_posiciones_filtered_original['time'].astype(str)

columns_to_normalize = ['x', 'y', 'velocity_x', 'velocity_y']

scaler = MinMaxScaler()
data_posiciones_filtered_normalized = data_posiciones_filtered
data_posiciones_filtered_normalized[columns_to_normalize] = scaler.fit_transform(data_posiciones_filtered[columns_to_normalize])
data_posiciones_filtered_normalized['team'] = data_posiciones_filtered_normalized['team'].map({1: -1, 2: 1, 0: 0})

# %%
data_posiciones_filtered_normalized.sample(7)
# Out:
#             id  match_id  player_id         x         y  velocity_x  \
# 87451   129099       212        117  0.272111  0.207115    0.228406
# 238913  299375       437        424  0.366399  0.565826    0.224213
# 170537  226178       347        326  0.075401  0.463235    0.223434
# 21590    46210        73          2  0.629118  0.619477    0.220199
# 178566  235403       360        325  0.511586  0.432117    0.237045
# 135760  184949       287        263  0.754637  0.186599    0.226822
# 216285  275780       409          0  0.415059  0.675272    0.233820
#
#         velocity_y        time  team  cant_de_duplicados
# 87451     0.348183  134.016667    -1                   1
# 238913    0.364448   35.066667     1                   1
# 170537    0.389669   96.033333    -1                   1
# 21590     0.347872  128.133333     1                   1
# 178566    0.381167  105.683333     1                   1
# 135760    0.360065   16.333333     1                   1
# ...

# %%
data_posiciones_filtered_original.sample(7)
# Out:
#             id  match_id  player_id           x           y  velocity_x  \
# 51850    83030       123        117  273.479082 -167.206532  -61.234434
# 18727    43347        70         63   86.904429  116.838623  126.048038
# 54382    85985       127          0  326.980018  -64.093616  283.164104
# 241843  302447       440        410 -216.567526  174.439934  -89.377758
# 64110    96601       140          2 -413.090783  -21.236048 -153.208544
# 60975    93155       135        124  482.698774 -104.418835   24.880676
# 82376   123926       206        117   18.058025  -95.950206   54.253980
#
#         velocity_y        time  team  cant_de_duplicados  \
# 51850   -23.221660   52.466667     2                   1
# 18727    84.149792   95.283333     1                   1
# 54382   -71.500844    5.333333     0                   1
# 241843   21.478746  190.816667     1                   1
# 64110   -17.324085  117.850000     1                   1
# ...

# %% [markdown]
# ## Modelos (esta parte se encuentra en desarrollo)

# %% [markdown]
# #### Para todos los n ticks (1 a 6)
# Se incluye:
# * El armado del modelo (red neuronal)
# * Analisis de prediccion de probabilidades en momentos tomados al azar
# * Analisis del momento del partido (grafico de la cancha) con las probabilidades predichas por el modelo

# %%
random_state = 42

# %% [markdown]
# ### Sexto modelo: SVM 006

# %%
cf_m.analizar_modelo_pkl(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'models/000_modelos_decentes/131_SVM_GridSearch_gol_4_ticks/',  # directorio donde está el modelo
    'gol_4_ticks',
    (220, 440),  # lista con ids de partidos a analizar en la sección de análisis puntual de todos los momentos de un partido
    'custom_evaluation_10_03_01' # Llama a la funcion evaluacion customizada
)

# %%
from scipy.stats import uniform, loguniform

#Probar (sin optimizar):
custom_param_grid_svm_00 = {
    'svm__C': loguniform(1e-3, 1e3),
    'svm__gamma': loguniform(1e-4, 1e1),
    'svm__kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'svm__degree': [2, 3, 4, 5],  # Solo relevante si kernel es 'poly'
    'svm__coef0': uniform(0, 1)  # Relevante para 'poly' y 'sigmoid'
}

# Solo para testear
custom_param_grid_svm_01 = {
    'svm__C': loguniform(1e-3, 1e3),
    'svm__gamma': loguniform(1e-4, 1e1),
    'svm__kernel': ['rbf'],
}

# Probar (mas optimizada):
custom_param_grid_svm_02 = {
    'svm__C': loguniform(1e-2, 1e2),  # Rango más razonable
    'svm__gamma': loguniform(1e-3, 1),  # Rango más estable
    'svm__kernel': ['linear', 'rbf', 'poly'],  # Eliminé 'sigmoid', que rara vez es útil
    'svm__degree': [2, 3, 4],  # Solo si kernel es 'poly'
    'svm__coef0': uniform(0, 0.5)  # Reducido a valores más realistas
}



custom_param_grid_svm_03 = {
    'svm__C': loguniform(1e-3, 1e3),          # Regularización
    'svm__gamma': loguniform(1e-4, 1e1),      # Influencia de cada punto de datos
    'svm__kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'svm__degree': [2, 3, 4, 5],              # Solo relevante si kernel es 'poly'
    'svm__coef0': uniform(0, 1),              # Relevante para 'poly' y 'sigmoid'
    
    # Nuevas opciones
    'svm__shrinking': [True, False],          # Si usa heurísticas para acelerar cálculos
    'svm__tol': loguniform(1e-5, 1e-1),       # Tolerancia para la convergencia
    'svm__class_weight': [None, 'balanced'],  # Penalización para clases desbalanceadas
    'svm__decision_function_shape': ['ovr', 'ovo'],  # Cómo manejar múltiples clases
    'svm__max_iter': [1000, 5000, -1],        # Límite de iteraciones (-1 = sin límite)
}

# %%
cf_m.modelar_svm_007(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks',
    custom_param_grid_svm_00 # Parametros customizados para el grid search.
)

# %%
cf_m.modelar_svm_007(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks',
    custom_param_grid_svm_01 # Parametros customizados para el grid search.
)
# Out:
# El id del modelo es 131.
#  Sus resultados se guardarán en la carpeta: models/131_SVM_GridSearch_gol_4_ticks/
# Contador de modelos actualizado.
#
# Algunas datos de X:
#  [[ 0.80017925  0.1609972   0.23689799  0.3670397  -1.          0.72212153
#    0.37543957  0.23493795  0.35449729  1.          0.52821746  0.26578071
#    0.23579786  0.3598105  -1.          0.54389744  0.47078433  0.23399483
#    0.34878041  1.          0.80627817  0.54673581  0.23336869  0.34854076
#   -1.          0.85777327  0.27872577  0.23189976  0.34544476  1.
#    0.92041035  0.18983064  0.2386954   0.36567474  0.        ]
#  [ 0.19875442  0.46672342  0.22585431  0.37051068  1.          0.1251821
#    0.89620236  0.22336731  0.37620233  1.          0.16626419  0.86473306
#    0.21538903  0.37622074 -1.          0.0941895   0.82999039  0.22152737
#    0.38609048 -1.          0.31079195  0.71549459  0.2191109   0.37067235
#   -1.          0.34244906  0.68645093  0.21903448  0.36666694  1.
# ...

# %% [markdown]
# ### Primer modelo: Red Neuronal 001
# Caracteristicas y parametros:
# * MLPClassifier de skLearn, con GridSearch + Cross Validation (5 folds)
# * Funcion en custom_functions_modelado:
#     * modelar_red_neuronal_001(
#         random_state,
#         background_image,
#         data_posiciones_grouped_filtered_labeled,
#         data_posiciones_filtered,
#         data_posiciones_filtered_original,
#         gol_n_ticks
#         )

# %%
cf_m.modelar_red_neuronal_001(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_1_ticks',
    True
    )

# %%
cf_m.modelar_red_neuronal_001(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_2_ticks',
    True
    )

# %%
cf_m.modelar_red_neuronal_001(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_3_ticks',
    True
    )

# %%
cf_m.modelar_red_neuronal_001(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks',
    True
    )

# %%
cf_m.modelar_red_neuronal_001(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_5_ticks',
    True
    )

# %%
cf_m.modelar_red_neuronal_001(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_6_ticks',
    True
    )

# %%
custom_match_id = 46
cf.plotear_partido_entero(
    data_posiciones_filtered_original,
    background_image,
    custom_match_id
    )

# %% [markdown]
# #### Para 4 ticks

# %% [markdown]
# ##### Modelo principal
# Se incluye:
# * El armado del modelo (red neuronal)
# * Analisis de prediccion de probabilidades en momentos tomados al azar
# * Analisis del momento del partido (grafico de la cancha) con las probabilidades predichas por el modelo

# %%
random_state = 900438094

# %%
cf_m.modelar_red_neuronal_001(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks'
    )

# %% [markdown]
# ##### GridSearchCV + Cross Validation (en desarrollo)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier

# Ejecutar la validación cruzada con 5 pliegues
scores = cross_val_score(modelo, X, y, cv=5)

# Mostrar las puntuaciones para cada pliegue
print("Puntuaciones por pliegue:", scores)

# Promedio de las puntuaciones
print("Puntuación media de la validación cruzada:", scores.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from sklearn.neural_network import MLPClassifier
#       4 # Ejecutar la validación cruzada con 5 pliegues
# ----> 5 scores = cross_val_score(modelo, X, y, cv=5)
#       7 # Mostrar las puntuaciones para cada pliegue
#       8 print("Puntuaciones por pliegue:", scores)
#
# NameError: name 'modelo' is not defined

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier

# Definir los parámetros a probar
param_grid = {
    'hidden_layer_sizes': [(128, 64, 32), (64, 32), (128, 128), (256, 128, 64)],
    'alpha': [0.001, 0.01, 0.1],
    'learning_rate_init': [0.001, 0.01]
}

# Configurar la búsqueda en cuadrícula con validación cruzada
grid_search = GridSearchCV(MLPClassifier(max_iter=500, random_state=random_state), param_grid, cv=5)

# Ajustar el modelo con los datos
grid_search.fit(X, y)


results_df = pd.DataFrame(grid_search.cv_results_)

# Seleccionar columnas relevantes para mostrar los resultados
results_df = results_df[['params', 'mean_test_score', 'rank_test_score']]

# Ordenar por la puntuación media en orden descendente
results_df = results_df.sort_values(by='mean_test_score', ascending=False)

# Mostrar las 10 mejores combinaciones
print("Top 10 combinaciones de parámetros:")
print(results_df.head(10))

# Mostrar todas las combinaciones ordenadas
print("\nTodas las combinaciones de parámetros ordenadas por puntuación:")
print(results_df)

# Ver los mejores parámetros encontrados
print("Mejores parámetros:", grid_search.best_params_)

# Ver la mejor puntuación obtenida
print("Mejor puntuación:", grid_search.best_score_)

# %%
# Hacer predicciones con el mejor modelo encontrado
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluar el modelo con el conjunto de prueba
print("Reporte de clasificación:\n", classification_report(y_test, y_pred))

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier

# Ejecutar la validación cruzada con 5 pliegues
scores = cross_val_score(best_model, X, y, cv=5)

# Mostrar las puntuaciones para cada pliegue
print("Puntuaciones por pliegue:", scores)

# Promedio de las puntuaciones
print("Puntuación media de la validación cruzada:", scores.mean())

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='viridis', fmt='d', cbar=False,
            xticklabels=['Gol Blue', 'Gol Red', 'Ningún gol'],
            yticklabels=['Gol Blue', 'Gol Red', 'Ningún gol'])
plt.xlabel('Predicción')
plt.ylabel('Real')
plt.title('Matriz de Confusión')
plt.show()

# %%
indices_y_test = y_test.index
match_id_time_test = data_posiciones_filtered.loc[indices_y_test,]
match_id_time_test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 indices_y_test = y_test.index
#       2 match_id_time_test = data_posiciones_filtered.loc[indices_y_test,]
#       3 match_id_time_test
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
from sklearn.model_selection import GridSearchCV

# Definir los parámetros a probar
param_grid = {
    #'hidden_layer_sizes': [(128, 64, 32), (64, 32), (128, 128), (256, 128, 64)],
    'hidden_layer_sizes': [(128, 64, 32), (64, 32), (64, 32, 16)],
    'alpha': [0.1, 1, 10],
    'learning_rate_init': [0.001, 0.01]
}

# Configurar la búsqueda en cuadrícula con validación cruzada
grid_search = GridSearchCV(MLPClassifier(max_iter=500, random_state=random_state), param_grid, cv=5, scoring='f1_weighted')

# Ajustar el modelo con los datos
grid_search.fit(X, y)

# Ver los mejores parámetros encontrados
print("Mejores parámetros:", grid_search.best_params_)

# Ver la mejor puntuación obtenida
print("Mejor puntuación:", grid_search.best_score_)
# Out:
# Mejores parámetros: {'alpha': 0.1, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate_init': 0.001}
# Mejor puntuación: 0.7029008706163224

# %%
# Hacer predicciones con el mejor modelo encontrado
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluar el modelo con el conjunto de prueba
print("Reporte de clasificación:\n", classification_report(y_test, y_pred))
# Out:
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#         Blue       1.00      0.99      1.00       120
#          Red       0.95      0.97      0.96       120
#         none       0.98      0.97      0.98       239
#
#     accuracy                           0.98       479
#    macro avg       0.98      0.98      0.98       479
# weighted avg       0.98      0.98      0.98       479

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier

# Ejecutar la validación cruzada con 5 pliegues
scores = cross_val_score(best_model, X, y, cv=5)

# Mostrar las puntuaciones para cada pliegue
print("Puntuaciones por pliegue:", scores)

# Promedio de las puntuaciones
print("Puntuación media de la validación cruzada:", scores.mean())
# Out:
# C:\Users\ASROCK\.conda\envs\env_modelado_haxball\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\ASROCK\.conda\envs\env_modelado_haxball\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Puntuaciones por pliegue: [0.725      0.6835443  0.75949367 0.78481013 0.70886076]
# Puntuación media de la validación cruzada: 0.7323417721518988
# C:\Users\ASROCK\.conda\envs\env_modelado_haxball\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='viridis', fmt='d', cbar=False,
            xticklabels=['Gol Blue', 'Gol Red', 'Ningún gol'],
            yticklabels=['Gol Blue', 'Gol Red', 'Ningún gol'])
plt.xlabel('Predicción')
plt.ylabel('Real')
plt.title('Matriz de Confusión')
plt.show()

# %% [markdown]
# ### Segundo modelo: Random Forest 002
# Caracteristicas y paramteros:
# * RandomForestClassifier de skLearn, con GridSearch + Cross Validation
# * Funcion en custom_functions_modelado:
#     * modelar_random_forest_002(
#     random_state,
#     background_image,
#     data_posiciones_grouped_filtered_labeled,
#     data_posiciones_filtered,
#     data_posiciones_filtered_original,
#     gol_n_ticks,
#     custom_param_grid_rf
# ):

# %%
random_state = 42

# %%
custom_class_weight_balanced = {
    'Blue': 1,  # Gol del equipo Blue
    'none': 1,  # Ningún gol
    'Red': 1   # Gol del equipo Red
}

custom_class_weight_RedBlue = {
    'Blue': 2,  # Gol del equipo Blue (favorecido)
    'none': 1,  # Ningún gol
    'Red': 2   # Gol del equipo Red (favorecido)
}

custom_class_weight_None = {
    'Blue': 1,  # Gol del equipo Blue
    'none': 2,  # Ningún gol (favorecido)
    'Red': 1   # Gol del equipo Red
}

custom_class_weight_None_02 = {
    'Blue': 1,  # Gol del equipo Blue
    'none': 1.5,  # Ningún gol (favorecido)
    'Red': 1   # Gol del equipo Red
}
        
        
custom_param_grid_rf_002 = {
    'n_estimators': [200, 500, 1000],  # Más estimadores pueden mejorar estabilidad
    'max_depth': [10, 30, 50, None],  # Profundidad alta, pero con opción ilimitada
    'min_samples_split': [5, 10, 20],  # Evita sobreajuste con más muestras requeridas
    'min_samples_leaf': [2, 4, 10],  # Tamaño mínimo de hojas para robustez
    'max_features': ['sqrt', 'log2', None],  # Evita sobreajuste y mejora eficiencia
    'bootstrap': [True, False],  # Evaluar si el muestreo mejora rendimiento
    'oob_score': [True, False],  # Activar *out-of-bag* para validación interna
    'criterion': ['gini', 'entropy'],  # Evaluar distintos criterios de impureza
    'class_weight': [
        custom_class_weight_balanced, 
        custom_class_weight_RedBlue, 
        custom_class_weight_None
    ]
}

custom_param_grid_rf_002a = {
    'n_estimators': [100, 200],  # Reducido a 2 opciones
    'max_depth': [10, 20, None],  # Reducido a 3 opciones
    'min_samples_split': [10, 20],  # Reducido a 2 opciones
    'min_samples_leaf': [4, 10],  # Reducido a 2 opciones
    'max_features': ['sqrt'],  # Solo una opción
    'bootstrap': [True],  # Fijado en True
    'oob_score': [False],  # Fijado en False
    'criterion': ['gini'],  # Solo un criterio
    'class_weight': [custom_class_weight_balanced, custom_class_weight_None]  # 2 opciones
}

custom_param_grid_rf_002b = {
    'n_estimators': [100],  # Más estimadores pueden mejorar estabilidad
    'max_depth': [10],  # Profundidad alta, pero con opción ilimitada
    'min_samples_split': [2],  # Evita sobreajuste con más muestras requeridas
    'min_samples_leaf': [1],  # Tamaño mínimo de hojas para robustez
    'max_features': ['sqrt'],  # Evita sobreajuste y mejora eficiencia
    'bootstrap': [True],  # Evaluar si el muestreo mejora rendimiento
    'oob_score': [True],  # Activar *out-of-bag* para validación interna
    'criterion': ['gini'],  # Evaluar distintos criterios de impureza
    'class_weight': [
        custom_class_weight_None, 
        'balanced_subsample'
    ]
}

custom_param_grid_rf_002c = {
    'n_estimators': [100, 200, 500], 
    'max_depth': [10, 20, None],  # Reducido a 3 opciones
    'min_samples_split': [10, 20],  # Reducido a 2 opciones
    'min_samples_leaf': [4, 10],  # Reducido a 2 opciones
    'max_features': ['sqrt', 'log2'],  
    'bootstrap': [True],  # Fijado en True
    'oob_score': [False],  # Fijado en False
    'criterion': ['gini', 'entropy'],  # Solo un criterio
    'class_weight': [custom_class_weight_balanced, custom_class_weight_None, custom_class_weight_RedBlue]  # 2 opciones
}

custom_param_grid_rf_002d = {
    'n_estimators': [500], 
    'max_depth': [20, None],  # Reducido a 3 opciones
    'min_samples_split': [10, 20],  # Reducido a 2 opciones
    'min_samples_leaf': [2, 4],  # Reducido a 2 opciones
    'max_features': ['sqrt', 'log2'],  
    'bootstrap': [True, False],  # Fijado en True
    'oob_score': [True, False],  # Fijado en False
    'criterion': ['entropy'],  # Solo un criterio
    'class_weight': [custom_class_weight_balanced]  # 2 opciones
}


custom_param_grid_rf_002e = {
    'n_estimators': [200], 
    'max_depth': [10, 15], 
    'min_samples_split': [20, 30], 
    'min_samples_leaf': [10, 20],  
    'max_features': ['log2', None],  
    'bootstrap': [True],  
    'oob_score': [False],  
    'criterion': ['entropy'],  
    'ccp_alpha': [0.0, 0.01, 0.03], # Agregamos pruning para reducir sobreajuste
    'max_leaf_nodes': [50, 100],  # Limitamos el crecimiento del árbol
    'class_weight': [custom_class_weight_balanced]
}

custom_param_grid_rf_002f = {
    'n_estimators': [200], 
    'max_depth': [10, 15], 
    'min_samples_split': [20, 30], 
    'min_samples_leaf': [10, 20],  
    'max_features': ['log2', None],  
    'bootstrap': [True],  
    'oob_score': [False],  
    'criterion': ['entropy'],  
    'ccp_alpha': [0.0, 0.01, 0.03], # Agregamos pruning para reducir sobreajuste
    'max_leaf_nodes': [50, 100],  # Limitamos el crecimiento del árbol
    'class_weight': [custom_class_weight_None_02]
}

# %%
cf_m.modelar_random_forest_002(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "gol_4_ticks",
    custom_param_grid_rf_002a # Parametros customizados para el grid search.
    )

# %%
cf_m.modelar_random_forest_002(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "gol_4_ticks",
    custom_param_grid_rf_002b # Parametros customizados para el grid search.
    )

# %%
cf_m.modelar_random_forest_002(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "gol_4_ticks",
    custom_param_grid_rf_002c # Parametros customizados para el grid search.
    )

# %%
cf_m.modelar_random_forest_002(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "gol_4_ticks",
    custom_param_grid_rf_002d # Parametros customizados para el grid search.
    )

# %%
cf_m.modelar_random_forest_002(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "gol_4_ticks",
    custom_param_grid_rf_002e # Parametros customizados para el grid search.
    )

# %%
cf_m.modelar_random_forest_002(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "gol_4_ticks",
    custom_param_grid_rf_002f # Parametros customizados para el grid search.
    )

# %% [markdown]
# ### Tercer modelo: TensorFlow 003
# Caracteristicas y paramteros:
# * Clasificador con Keras de TensorFlow
# * Funcion en custom_functions_modelado:
#     * modelar_tensorflow_003(
#     random_state,
#     background_image,
#     data_posiciones_grouped_filtered_labeled,
#     data_posiciones_filtered,
#     data_posiciones_filtered_original,
#     gol_n_ticks
# ):

# %%
cf_m.modelar_tensorflow_003(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks'
)

# %%
cf_m.analizar_modelo(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "models/75_TensorFlow003_gol_1_ticks/", # directorio donde está el modelo
    'gol_1_ticks',
    56 # id del partido a analizar en la sección de analisis puntual de todos los momentos de un partido
)

# %%
cf_m.analizar_modelo_pkl(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "models/74_RandomSearch_RF_gol_4_ticks/", # directorio donde está el modelo
    'gol_4_ticks',
    315 # id del partido a analizar en la sección de analisis puntual de todos los momentos de un partido
)

# %%
# --- Librerias del modelo ---
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import keras_tuner as kt


# Verificar que TensorFlow está utilizando solamente la CPU
if not tf.config.list_physical_devices('GPU'):
    print("TensorFlow está configurado para usar únicamente la CPU.")
else:
    print("Advertencia: TensorFlow está utilizando la GPU.")
# Out:
# TensorFlow está configurado para usar únicamente la CPU.

# %%
print(tf.config.threading.get_intra_op_parallelism_threads())
print(tf.config.threading.get_inter_op_parallelism_threads())
# Out:
# 3
# 0

# %%
print("GPUs disponibles: ", tf.config.list_physical_devices('GPU'))
# Out:
# GPUs disponibles:  []

# %% [markdown]
# ### Cuarto modelo: RandomSearch Random Forest 004
# Caracteristicas y paramteros:
# * RandomForestClassifier de skLearn, con RandomSearch + Cross Validation
# * Funcion en custom_functions_modelado:
#     * modelar_randomsearch_rf_004(
#     random_state,
#     background_image,
#     data_posiciones_grouped_filtered_labeled,
#     data_posiciones_filtered,
#     data_posiciones_filtered_original,
#     gol_n_ticks,
#     custom_param_grid_rf,
#     combinaciones
#     ):

# %%
custom_class_weight_balanced = {
    'Blue': 1,  # Gol del equipo Blue
    'none': 1,  # Ningún gol
    'Red': 1   # Gol del equipo Red
}

custom_class_weight_RedBlue = {
    'Blue': 2,  # Gol del equipo Blue (favorecido)
    'none': 1,  # Ningún gol
    'Red': 2   # Gol del equipo Red (favorecido)
}

custom_class_weight_None = {
    'Blue': 1,  # Gol del equipo Blue
    'none': 2,  # Ningún gol (favorecido)
    'Red': 1   # Gol del equipo Red
}

custom_class_weight_None_02 = {
    'Blue': 1,  # Gol del equipo Blue
    'none': 1.5,  # Ningún gol (favorecido)
    'Red': 1   # Gol del equipo Red
}

custom_param_grid_rf_004 = {
    'n_estimators': [150, 200, 350, 500, 1000],  # Más estimadores pueden mejorar estabilidad
    'max_depth': [10, 30, 50, None],  # Profundidad alta, pero con opción ilimitada
    'min_samples_split': [5, 10, 20],  # Evita sobreajuste con más muestras requeridas
    'min_samples_leaf': [4, 8, 10, 20],  # Tamaño mínimo de hojas para robustez
    'max_features': ['sqrt', 'log2', None],  # Evita sobreajuste y mejora eficiencia
    'bootstrap': [True, False],  # Evaluar si el muestreo mejora rendimiento
    'oob_score': [True, False],  # Activar *out-of-bag* para validación interna
    'criterion': ['gini', 'entropy'],  # Evaluar distintos criterios de impureza
    'ccp_alpha': [0.0, 0.005, 0.01, 0.03], # Agregamos pruning para reducir sobreajuste
    'max_leaf_nodes': [25, 50, 75, 100],  # Limitamos el crecimiento del árbol
    'class_weight': [
        custom_class_weight_balanced, 
        custom_class_weight_RedBlue, 
        custom_class_weight_None,
        custom_class_weight_None_02
    ]
}

custom_param_grid_rf_004a = {
    'n_estimators': [500],  # Número de árboles
    'max_depth': [10, 20, None],  # Profundidad máxima de los árboles
    'min_samples_split': [10, 20],  # Mínimo de muestras para dividir un nodo
    'min_samples_leaf': [4, 10],  # Mínimo de muestras en una hoja
    'max_features': ['sqrt', 'log2'],  # Número de características para dividir
    'bootstrap': [True],  # Usar bootstrap (muestreo con reemplazo)
    'oob_score': [False],  # No calcular out-of-bag score (ahorra tiempo)
    'criterion': ['gini', 'entropy'],  # Criterio de división
    'class_weight': [custom_class_weight_balanced]  # Pesos de clase
}


custom_param_grid_rf_004b = {
    'n_estimators': [500],  # Número de árboles
    'max_depth': [10, 20, None],  # Profundidad máxima de los árboles
    'min_samples_split': [10, 20],  # Mínimo de muestras para dividir un nodo
    'min_samples_leaf': [4, 10],  # Mínimo de muestras en una hoja
    'max_features': ['sqrt', 'log2'],  # Número de características para dividir
    'bootstrap': [True],  # Usar bootstrap (muestreo con reemplazo)
    'oob_score': [False],  # No calcular out-of-bag score (ahorra tiempo)
    'criterion': ['gini', 'entropy'],  # Criterio de división
    'class_weight': [custom_class_weight_None]  # Pesos de clase
}


custom_param_grid_rf_004c = {
    'n_estimators': [1000],  # Número de árboles
    'max_depth': [10, 20, 40, None],  # Profundidad máxima de los árboles
    'min_samples_split': [30, 40],  # Mínimo de muestras para dividir un nodo
    'min_samples_leaf': [5, 10, 20],  # Mínimo de muestras en una hoja
    'max_features': ['sqrt', 'log2'],  # Número de características para dividir
    'bootstrap': [True],  # Usar bootstrap (muestreo con reemplazo)
    'oob_score': [False],  # No calcular out-of-bag score (ahorra tiempo)
    'criterion': ['gini', 'entropy'],  # Criterio de división
    'class_weight': [custom_class_weight_None]  # Pesos de clase
}


custom_param_grid_rf_004m = {
    'n_estimators': [1000, 1500, 2000],  # Rango de árboles a explorar
    'max_depth': [5, 10, 15, 20, None],  # Profundidad máxima del árbol (None no limita)
    'min_samples_split': [2, 5, 10, 20, 30],  # Mínimo de muestras para dividir un nodo
    'min_samples_leaf': [2, 4, 6, 8, 10],  # Mínimo de muestras en una hoja
    'max_features': ['sqrt', 'log2', None, 0.5, 0.75],  # Número de características para dividir
    'bootstrap': [True],  # Usar bootstrap (muestreo con reemplazo)
    'oob_score': [True, False],  # Calcular out-of-bag score (puede ayudar con la generalización)
    'criterion': ['gini', 'entropy'],  # Criterio de división
    'class_weight': [custom_class_weight_balanced, None],  # Pesos de clase
    'warm_start': [True, False],  # Reutilizar soluciones de árboles anteriores para ahorrar tiempo
    'max_samples': [0.8, 0.9, None],  # Submuestra de los datos de entrenamiento en cada árbol
}





random_state_37 = 37
random_state_8032 = 8032
random_state_906 = 906
random_state_330519 = 330519

# %%
cf_m.modelar_randomsearch_rf_004(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks',
    #custom_class_weight, # Pesos de las clases customizados para el random forest.
    custom_param_grid_rf_004a, # Parametros customizados para el grid search.
    25 # Cantidad de combinaciones a probar
    )

# %%
cf_m.modelar_randomsearch_rf_004(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks',
    #custom_class_weight, # Pesos de las clases customizados para el random forest.
    custom_param_grid_rf_004b, # Parametros customizados para el grid search.
    25 # Cantidad de combinaciones a probar
    )

# %%
cf_m.modelar_randomsearch_rf_004(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks',
    #custom_class_weight, # Pesos de las clases customizados para el random forest.
    custom_param_grid_rf_004c, # Parametros customizados para el grid search.
    25 # Cantidad de combinaciones a probar
    )

# %%
cf_m.modelar_randomsearch_rf_004(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks',
    custom_param_grid_rf_004m, # Parametros customizados para el grid search.
    25 # Cantidad de combinaciones a probar
    )

# %%
cf_m.analizar_modelo_pkl(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "models/82_RandomSearch_RF_gol_4_ticks/", # directorio donde está el modelo
    'gol_4_ticks',
    440 # id del partido a analizar en la sección de analisis puntual de todos los momentos de un partido
)

# %%
cf_m.analizar_modelo_pkl(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "models/83_RandomSearch_RF_gol_4_ticks/", # directorio donde está el modelo
    'gol_4_ticks',
    440 # id del partido a analizar en la sección de analisis puntual de todos los momentos de un partido
)

# %%
cf_m.analizar_modelo_pkl(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    "models/84_RandomSearch_RF_gol_4_ticks/", # directorio donde está el modelo
    'gol_4_ticks',
    440 # id del partido a analizar en la sección de analisis puntual de todos los momentos de un partido
)

# %% [markdown]
# ### Quinto modelo

# %%
# Pesos para las clases
class_weight_balanced = {0: 0.33, 1: 0.33, 2: 0.34}

# %%
cf_m.modelar_tensorflow_simple_005(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_3_ticks',
    class_weight_balanced
    )

# %%
set_de_partidos_chico_01 = (46, 279, 433)
set_de_partidos_grande_01 = (55, 88, 101, 116, 218, 244, 273, 314, 399, 419, 440)

# %%
cf_m.analizar_modelo_tf_005(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'models/112_TensorFlow_Simplificado_gol_3_ticks/',  # directorio donde está el modelo
    'gol_3_ticks',
    set_de_partidos_chico_01,  # ids de los partidos a analizar en la sección de análisis puntual de todos los momentos de un partido
    'custom_evaluation_10_03_01' # Llama a la funcion evaluacion customizada
    )

# %%
cf_m.modelar_tensorflow_006(
    random_state,
    background_image,
    data_posiciones_grouped_filtered_labeled,
    data_posiciones_filtered,
    data_posiciones_filtered_original,
    'gol_4_ticks',
    class_weight_balanced
    )

# %% [markdown]
# ### ...etc... (no correr)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Definir el modelo
model = Sequential([
    Dense(128, input_dim=X.shape[1], activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')  # Salida para 3 clases: ninguno, gol rojo, gol azul
])

# Compilar el modelo
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Entrenar el modelo
history = model.fit(X, y.argmax(axis=1), epochs=50, batch_size=32, validation_split=0.2)

# %%
loss, accuracy = model.evaluate(X, y.argmax(axis=1))
print(f"Loss: {loss}, Accuracy: {accuracy}")

# %%
# Predecir probabilidades para cada entrada
predicciones_probabilidades = model.predict(X)

# Convertir las probabilidades en clases (0, 1, 2)
predicciones_clases = predicciones_probabilidades.argmax(axis=1)

# %%
import pandas as pd

# Crear un DataFrame para analizar
resultados = pd.DataFrame({
    'match_id': data_posiciones_grouped_filtered_labeled['match_id'],
    'time': data_posiciones_grouped_filtered_labeled['time'],
    'prediccion_clase': predicciones_clases,
    'gol_verdadero': y.argmax(axis=1),  # Convertir las etiquetas verdaderas en la misma forma
    'prob_nada': predicciones_probabilidades[:, 0],
    'prob_gol_rojo': predicciones_probabilidades[:, 1],
    'prob_gol_azul': predicciones_probabilidades[:, 2],
})

# Mostrar los primeros resultados
print(resultados.sample(10))

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Generar un informe de clasificación
print(classification_report(y.argmax(axis=1), predicciones_clases, target_names=['Ningún gol', 'Gol rojo', 'Gol azul']))

# Matriz de confusión
print(confusion_matrix(y.argmax(axis=1), predicciones_clases))
